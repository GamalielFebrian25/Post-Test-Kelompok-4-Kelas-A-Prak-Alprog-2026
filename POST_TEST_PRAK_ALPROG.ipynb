# %% [markdown]
# <a href="https://colab.research.google.com/github/GamalielFebrian25/Post-Test-Kelompok-4-Kelas-A-Prak-Alprog-2026/blob/main/POST_TEST_PRAK_ALPROG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analisis Gender Inequality Index - Kelompok 4
#
# Notebook ini mengerjakan seluruh soal Kelompok 4 untuk Kategori A, B, C, dan D menggunakan Python.
#
# Library yang digunakan: `pandas`, `matplotlib`, dan `seaborn`.

# %%
# %pip install pandas matplotlib seaborn numpy

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

CSV_PATH = 'Kelas A_Gender Inequality Index.csv'
OUTPUT_DIR = "kelompok4_ipynb_output"

os.makedirs(OUTPUT_DIR, exist_ok=True)
sns.set_theme(style="whitegrid")

# %% [markdown]
# ## Load Dataset
#
# Bagian ini membaca file CSV dan membersihkan kolom numerik agar bisa dihitung dengan benar.

# %%
df = pd.read_csv(CSV_PATH)

numeric_columns = [
    "GII",
    "Rank",
    "Maternal_mortality",
    "Adolescent_birth_rate",
    "Seats_parliament",
    "F_secondary_educ",
    "M_secondary_educ",
    "F_Labour_force",
    "M_Labour_force",
]

for column in numeric_columns:
    df[column] = pd.to_numeric(df[column], errors="coerce")

display(df.head())
# Out:
#        Country Human_development    GII  Rank  Maternal_mortality  \
# 0  Switzerland         Very high  0.018   3.0                 5.0
# 1       Norway         Very high  0.016   2.0                 2.0
# 2      Iceland         Very high  0.043   8.0                 4.0
# 3    Hong Kong         Very high    NaN   NaN                 NaN
# 4    Australia         Very high  0.073  19.0                 6.0
#
#    Adolescent_birth_rate  Seats_parliament  F_secondary_educ  \
# 0                    2.2              39.8              96.9
# 1                    2.3              45.0              99.1
# 2                    5.4              47.6              99.8
# 3                    1.6               NaN              77.1
# 4                    8.1              37.9              94.6
#
#    M_secondary_educ  F_Labour_force  M_Labour_force
# 0              97.5            61.7            72.7
# 1              99.3            60.3            72.0
# ...

# %% [markdown]
# ## Kategori A
#
# Tentukan nilai median dari tingkat kelahiran remaja (`Adolescent_birth_rate`) berdasarkan kelompok `Human_development`. Tampilkan dalam Bar Chart.

# %%
# 1. Logika Data
kategori_b = (
    df[(df["F_secondary_educ"] < 50) & df["Rank"].notna()]
    .sort_values("Rank", ascending=False)
    .head(10)
    [["Country", "Human_development", "Rank", "GII", "F_secondary_educ"]]
)

kategori_b.to_csv(
    os.path.join(OUTPUT_DIR, "kategori_B_rank_terburuk_f_secondary_lt50.csv"),
    index=False,
)
display(kategori_b)

# 2. Visualisasi Individu
plt.figure(figsize=(11, 6))
sns.barplot(
    data=kategori_b,
    x="F_secondary_educ",
    y="Country",
    palette="magma",
)
plt.title("10 Negara dengan Rank GII Terburuk (Pend. Perempuan < 50%)")
plt.xlabel("Pendidikan Menengah Perempuan (%)")
plt.ylabel("Negara")
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, "kategori_B_bar_chart.png"), dpi=300)
plt.show()
# Out:
#                       Country Human_development   Rank    GII  \
# 182                     Yemen               Low  170.0  0.820
# 156          Papua New Guinea            Medium  169.0  0.725
# 163                   Nigeria               Low  168.0  0.680
# 179               Afghanistan               Low  167.0  0.678
# 187  Central African Republic               Low  166.0  0.672
# 189                      Chad               Low  165.0  0.652
# 177                   Liberia               Low  164.0  0.648
# 162                     Haiti               Low  163.0  0.635
# 180              Sierra Leone               Low  162.0  0.633
# 157                Mauritania            Medium  161.0  0.632
#
#      F_secondary_educ
# 182              22.4
# 156              10.8
# 163              40.4
# 179               6.4
# 187              13.9
# 189               7.7
# 177              20.8
# 162              27.9
# 180              34.7
# 157              14.5
# ...

# %% [markdown]
# ## Kategori B
#
# Cari 10 negara dengan peringkat `Rank` GII terburuk atau tertinggi yang tingkat pendidikan perempuannya (`F_secondary_educ`) masih di bawah 50%. Tampilkan data pendidikannya dalam Bar Chart.

# %%
# 1. Logika Data
kategori_b = (
    df[(df["F_secondary_educ"] < 50) & df["Rank"].notna()]
    .sort_values("Rank", ascending=False)
    .head(10)
    [["Country", "Human_development", "Rank", "GII", "F_secondary_educ"]]
)

kategori_b.to_csv(
    os.path.join(OUTPUT_DIR, "kategori_B_rank_terburuk_f_secondary_lt50.csv"),
    index=False,
)
display(kategori_b)

# 2. Visualisasi Individu
plt.figure(figsize=(11, 6))
sns.barplot(
    data=kategori_b,
    x="F_secondary_educ",
    y="Country",
    palette="magma",
)
plt.title("10 Negara dengan Rank GII Terburuk (Pend. Perempuan < 50%)")
plt.xlabel("Pendidikan Menengah Perempuan (%)")
plt.ylabel("Negara")
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, "kategori_B_bar_chart.png"), dpi=300)
plt.show()
# Out:
#                       Country Human_development   Rank    GII  \
# 182                     Yemen               Low  170.0  0.820
# 156          Papua New Guinea            Medium  169.0  0.725
# 163                   Nigeria               Low  168.0  0.680
# 179               Afghanistan               Low  167.0  0.678
# 187  Central African Republic               Low  166.0  0.672
# 189                      Chad               Low  165.0  0.652
# 177                   Liberia               Low  164.0  0.648
# 162                     Haiti               Low  163.0  0.635
# 180              Sierra Leone               Low  162.0  0.633
# 157                Mauritania            Medium  161.0  0.632
#
#      F_secondary_educ
# 182              22.4
# 156              10.8
# 163              40.4
# 179               6.4
# 187              13.9
# 189               7.7
# 177              20.8
# 162              27.9
# 180              34.7
# 157              14.5
# ...

# %% [markdown]
# ## Kategori C
#
# Lakukan perhitungan matriks korelasi `.corr()` antar seluruh variabel numerik khusus untuk status `Human_development` Medium dan Low. Tampilkan dalam Heatmap.

# %%
# 1. Logika Data
df_c = df[df["Human_development"].isin(["Medium", "Low"])]
df_num_c = df_c.select_dtypes(include=[np.number])
korelasi_c = df_num_c.corr()

korelasi_c.to_csv(os.path.join(OUTPUT_DIR, "kategori_C_korelasi_medium_low.csv"))
display(korelasi_c)

# 2. Visualisasi Individu
plt.figure(figsize=(10, 8))
sns.heatmap(
    korelasi_c,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
    )
plt.title("Matriks Korelasi (Medium & Low)")
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, "kategori_C_heatmap.png"), dpi=300)
plt.show()
# Out:
#                             GII      Rank  Maternal_mortality  \
# GII                    1.000000  0.975800            0.644572
# Rank                   0.975800  1.000000            0.706790
# Maternal_mortality     0.644572  0.706790            1.000000
# Adolescent_birth_rate  0.516477  0.584865            0.547464
# Seats_parliament      -0.499001 -0.466073           -0.034608
# F_secondary_educ      -0.531777 -0.546921           -0.431270
# M_secondary_educ      -0.417474 -0.430776           -0.331833
# F_Labour_force        -0.029249  0.049283            0.245373
# M_Labour_force        -0.114475 -0.075134           -0.052511
#
#                        Adolescent_birth_rate  Seats_parliament  \
# GII                                 0.516477         -0.499001
# Rank                                0.584865         -0.466073
# Maternal_mortality                  0.547464         -0.034608
# Adolescent_birth_rate               1.000000          0.109642
# ...

# %% [markdown]
# ## Kategori D
#
# Tampilkan sebaran data kematian ibu (`Maternal_mortality`) antar kelompok `Human_development` dalam Boxplot.

# %%
# 1. Logika Data
kategori_d = df.dropna(subset=["Human_development", "Maternal_mortality"])

summary_d = kategori_d.groupby("Human_development")["Maternal_mortality"].describe()
summary_d.to_csv(os.path.join(OUTPUT_DIR, "kategori_D_summary_maternal_mortality.csv"))
display(summary_d)

# 2. Visualisasi Individu
plt.figure(figsize=(9, 6))
sns.boxplot(
    data=kategori_d,
    x="Human_development",
    y="Maternal_mortality",
    palette="Set2",
)
# Out:
#                    count        mean         std    min     25%    50%  \
# Human_development
# High                46.0   58.086957   49.535992    7.0   27.00   43.0
# Low                 32.0  521.468750  266.503160  140.0  331.25  480.0
# Medium              42.0  197.642857  165.107182   17.0   89.00  144.5
# Very high           62.0   13.983871   15.488221    2.0    5.00    8.0
#
#                       75%     max
# Human_development
# High                78.00   252.0
# Low                607.25  1150.0
# Medium             247.75   766.0
# Very high           17.00    70.0
# /tmp/ipykernel_3216/4067945554.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# <Axes: xlabel='Human_development', ylabel='Maternal_mortality'>

# %% [markdown]
# ## OUTPUT WAJIB: Grafik 5 (Gabungan)
#
# Menggabungkan seluruh visualisasi Kategori A, B, C, dan D dalam satu layout grid 2x2 menggunakan pendekatan objek `ax=axes[x, y]` tanpa menulis ulang logika datanya (memanggil ulang variabel yang sudah dihitung).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Memastikan df, OUTPUT_DIR sudah terdefinisi dari sel sebelumnya
# Jika tidak, Anda perlu menjalankannya terlebih dahulu

# 1. Logika Data untuk Kategori A (ditambahkan untuk memperbaiki error)
kategori_a = (
    df.dropna(subset=["Human_development", "Adolescent_birth_rate"])
    .groupby("Human_development")["Adolescent_birth_rate"]
    .median()
    .reset_index()
)
kategori_a = kategori_a.rename(columns={"Adolescent_birth_rate": "Median_Adolescent_birth_rate"})

# Membuat layout grid 2x2
fig, axes = plt.subplots(2, 2, figsize=(16, 12))
fig.suptitle("Analisis Gender Inequality Index (GII) - Kelompok 4", fontsize=18, fontweight="bold")

# Grafik 1 (Kategori A) di grid kiri atas
sns.barplot(data=kategori_a, x="Human_development", y="Median_Adolescent_birth_rate", ax=axes[0, 0], palette="viridis")
axes[0, 0].set_title("Kategori A: Median Kelahiran Remaja")
axes[0, 0].set_xlabel("Human Development")
axes[0, 0].set_ylabel("Median Adolescent Birth Rate")

# Grafik 2 (Kategori B) di grid kanan atas
sns.barplot(data=kategori_b, x="F_secondary_educ", y="Country", ax=axes[0, 1], palette="magma")
axes[0, 1].set_title("Kategori B: 10 Rank GII Terburuk (Pend. < 50%)")
axes[0, 1].set_xlabel("Pendidikan Menengah Perempuan (%)")
axes[0, 1].set_ylabel("Negara")

# Grafik 3 (Kategori C) di grid kiri bawah
sns.heatmap(korelasi_c, annot=True, cmap="coolwarm", fmt=".2f", ax=axes[1, 0])
axes[1, 0].set_title("Kategori C: Matriks Korelasi (Medium & Low)")

# Grafik 4 (Kategori D) di grid kanan bawah
sns.boxplot(data=kategori_d, x="Human_development", y="Maternal_mortality", ax=axes[1, 1], palette="Set2")
axes[1, 1].set_title("Kategori D: Distribusi Maternal Mortality")
axes[1, 1].set_xlabel("Human Development")
axes[1, 1].set_ylabel("Maternal Mortality")

# Merapikan dan menyimpan grafik gabungan
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, "Grafik_5_Gabungan_Kelompok4.png"), dpi=300)
plt.show()
# Out:
# /tmp/ipykernel_3216/2392685029.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=kategori_a, x="Human_development", y="Median_Adolescent_birth_rate", ax=axes[0, 0], palette="viridis")
# /tmp/ipykernel_3216/2392685029.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=kategori_b, x="F_secondary_educ", y="Country", ax=axes[0, 1], palette="magma")
# /tmp/ipykernel_3216/2392685029.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...
